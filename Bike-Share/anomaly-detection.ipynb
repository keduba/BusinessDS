# %% [markdown]
# # Introduction
# - First load the packages that will be used.
# - Load the data

# %% [markdown]
# import numpy as np
# from sklearn.ensemble import IsolationForest
# import matplotlib.pyplot as plt
#
# # Generate sample data
# np.random.seed(0)
# n_samples = 100
# n_outliers = 10
# X = np.random.randn(n_samples, 2)
# X_outliers = np.random.uniform(-5, 5, size=(n_outliers, 2))
# X = np.vstack((X, X_outliers))
#
# # Create an Isolation Forest model
# iforest = IsolationForest(contamination=0.1)
#
# # Fit the model to the data
# iforest.fit(X)
#
# # Predict anomalies
# y_pred = iforest.predict(X)
#
# # Visualize the results
# plt.figure(figsize=(8, 6))
# plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], c='blue', label='Inliers')
# plt.scatter(X[y_pred == -1, 0], X[y_pred == -1, 1], c='red', label='Outliers')
# plt.legend()
# plt.show()

# %%
import numpy as np
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# %%
# Generate sample data
np.random.seed(0)
n_samples = 100
n_outliers = 10
X = np.random.randn(n_samples, 2)
X_outliers = np.random.uniform(-5, 5, size=(n_outliers, 2))

# %%
X_outliers;

# %%
# merge both
np.vstack((X, X_outliers));

# %%
# Create an Isolation Forest model
iforest = IsolationForest(contamination=0.1)

""" Note: you should provide the level of contamination if you know it. Default value is auto, set based on the paper. 
Otherwise a value in range [0,0.5]. It tells you the proportion of outliers in the dataset.
Should you always know the level of contamination in advance before calling the model?
"""

# %%
# Fit the model
iforest.fit(X)
# Out:
# IsolationForest(contamination=0.1)

# %%
# Predict anomalies
y_pred = iforest.predict(X)

# %%
# Visualize the results
plt.figure(figsize=(8, 6))
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], c='blue', label='Inliers')
plt.scatter(X[y_pred == -1, 0], X[y_pred == -1, 1], c='red', label='Outliers')
plt.legend()
plt.show()

# %%
plt.scatter(X, X, c="blue", alpha=0.6)

# %% [markdown]
# A simple model to explore the anomaly in the dataset and where they lie.
